# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# <html>
# <head>
#     <title></title>
#     <style type="text/css">
#         h1
#         {
#             color: BLUE
#         }
#     </style>
# </head>
# <body>
#     <h1>Inicializando el DATAFRAME </h1>
# </body>
# </html>

# %%
datos = pd.read_csv("games.csv")
datos.head(2) #muestra la cantidad de elementos que queremos ver
#datos.describe()
# Out:
#    Id       Title  Release Date  \
# 0   0  Elden Ring  Feb 25, 2022
# 1   1       Hades  Dec 10, 2019
#
#                                              Team  Rating Times Listed  \
# 0  ['Bandai Namco Entertainment', 'FromSoftware']     4.5         3.9K
# 1                            ['Supergiant Games']     4.3         2.9K
#
#   Number of Reviews                                    Genres  \
# 0              3.9K                      ['Adventure', 'RPG']
# 1              2.9K  ['Adventure', 'Brawler', 'Indie', 'RPG']
#
#                                              Summary  \
# 0  Elden Ring is a fantasy, action and open world...
# 1  A rogue-lite hack and slash dungeon crawler in...
#
#                                              Reviews Plays Playing Backlogs  \
# 0  ["The first playthrough of elden ring is one o...   17K    3.8K     4.6K
# 1  ['convinced this is a roguelike for people who...   21K    3.2K     6.3K
#
#   Wishlist
# 0     4.8K
# 1     3.6K

# %% [markdown]
# <html>
# <head>
#     <title></title>
#     <style type="text/css">
#         h1
#         {
#             color: BLUE
#         }
#     </style>
# </head>
# <body>
#     <h1>Dimension del database </h1>
# </body>
# </html>

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1512 entries, 0 to 1511
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Id                 1512 non-null   int64
#  1   Title              1512 non-null   object
#  2   Release Date       1512 non-null   object
#  3   Team               1511 non-null   object
#  4   Rating             1499 non-null   float64
#  5   Times Listed       1512 non-null   object
#  6   Number of Reviews  1512 non-null   object
#  7   Genres             1512 non-null   object
#  8   Summary            1511 non-null   object
#  9   Reviews            1512 non-null   object
#  10  Plays              1512 non-null   object
#  11  Playing            1512 non-null   object
#  12  Backlogs           1512 non-null   object
#  13  Wishlist           1512 non-null   object
# dtypes: float64(1), int64(1), object(12)
# memory usage: 165.5+ KB

# %% [markdown]
# <html>
# <head>
#     <title></title>
#     <style type="text/css">
#         h1
#         {
#             color: BLUE
#         }
#     </style>
# </head>
# <body>
#     <h1>MOSTRANDO LAS FILAS DE DATOS NULOS </h1>
# </body>
# </html>

# %%
datos.isnull()
# Out:
#          Id  Title  Release Date   Team  Rating  Times Listed  \
# 0     False  False         False  False   False         False
# 1     False  False         False  False   False         False
# 2     False  False         False  False   False         False
# 3     False  False         False  False   False         False
# 4     False  False         False  False   False         False
# ...     ...    ...           ...    ...     ...           ...
# 1507  False  False         False  False   False         False
# 1508  False  False         False  False   False         False
# 1509  False  False         False  False   False         False
# 1510  False  False         False  False   False         False
# 1511  False  False         False  False   False         False
#
#       Number of Reviews  Genres  Summary  Reviews  Plays  Playing  Backlogs  \
# 0                 False   False    False    False  False    False     False
# ...

# %% [markdown]
# <html>
# <head>
#     <title></title>
#     <style type="text/css">
#         h1
#         {
#             color: BLUE
#         }
#     </style>
# </head>
# <body>
#     <h1>ELIMINANDO LOS DATOS NULOS DEL DATASET </h1>
# </body>
# </html>

# %%
data_sin_nulos = datos.dropna()
data_sin_nulos
# Out:
#         Id                                    Title  Release Date  \
# 0        0                               Elden Ring  Feb 25, 2022
# 1        1                                    Hades  Dec 10, 2019
# 2        2  The Legend of Zelda: Breath of the Wild  Mar 03, 2017
# 3        3                                Undertale  Sep 15, 2015
# 4        4                            Hollow Knight  Feb 24, 2017
# ...    ...                                      ...           ...
# 1507  1507             Back to the Future: The Game  Dec 22, 2010
# 1508  1508                        Team Sonic Racing  May 21, 2019
# 1509  1509                           Dragon's Dogma  May 22, 2012
# 1510  1510                          Baldur's Gate 3  Oct 06, 2020
# 1511  1511                 The LEGO Movie Videogame  Feb 04, 2014
#
#                                                    Team  Rating Times Listed  \
# 0        ['Bandai Namco Entertainment', 'FromSoftware']     4.5         3.9K
# ...

# %% [markdown]
# <html>
# <head>
#     <title></title>
#     <style type="text/css">
#         h1
#         {
#             color: BLUE
#         }
#     </style>
# </head>
# <body>
#     <h1>FUNCION PARA VERIFICAR SI EL GENERO "RPG" ESTA PRESENTE EN LA LISTA </h1>
# </body>
# </html>

# %%
def rpg(genres):
    return "RPG" in genres

#Aplica el filtro utiizando aplly
datos_RPG = datos[datos["Genres"].apply(rpg)]

#Muestra el dataset solamente incluyendi la columnas TITULO y RANKING
nombreRPG = datos_RPG[["Title", "Rating"]]
nombreRPG.head(10)
# Out:
#                                       Title  Rating
# 0                                Elden Ring     4.5
# 1                                     Hades     4.3
# 2   The Legend of Zelda: Breath of the Wild     4.4
# 3                                 Undertale     4.2
# 6                                     Omori     4.2
# 9                            NieR: Automata     4.3
# 10                          Persona 5 Royal     4.4
# 12                               God of War     4.2
# 14                               Bloodborne     4.5
# 16                                 Yakuza 0     4.4

# %% [markdown]
# <html>
# <head>
#     <title></title>
#     <style type="text/css">
#         h1
#         {
#             color: BLUE
#         }
#     </style>
# </head>
# <body>
#     <h1>INFORMACION DEL DATASET YA FILTRADO </h1>
# </body>
# </html>

# %%
nombreRPG.info
# Out:
# <bound method DataFrame.info of                                         Title  Rating
# 0                                  Elden Ring     4.5
# 1                                       Hades     4.3
# 2     The Legend of Zelda: Breath of the Wild     4.4
# 3                                   Undertale     4.2
# 6                                       Omori     4.2
# ...                                       ...     ...
# 1487                          Lisa the Joyful     3.7
# 1489            Kingdoms of Amalur: Reckoning     3.2
# 1500                        Children of Morta     3.4
# 1509                           Dragon's Dogma     3.7
# 1510                          Baldur's Gate 3     4.1
#
# [523 rows x 2 columns]>

# %% [markdown]
# <html>
# <head>
#     <title></title>
#     <style type="text/css">
#         h1
#         {
#             color: BLUE
#         }
#     </style>
# </head>
# <body>
#     <h1>IDENTIFICANDO SI EXISTEN DATOS NULOS EN EL NUEVO DATASET </h1>
# </body>
# </html>

# %%
nombreRPG.isnull()
# Out:
#       Title  Rating
# 0     False   False
# 1     False   False
# 2     False   False
# 3     False   False
# 6     False   False
# ...     ...     ...
# 1487  False   False
# 1489  False   False
# 1500  False   False
# 1509  False   False
# 1510  False   False
#
# [523 rows x 2 columns]

# %% [markdown]
# <html>
# <head>
#     <title></title>
#     <style type="text/css">
#         h1
#         {
#             color: BLUE
#         }
#     </style>
# </head>
# <body>
#     <h1>MOSTRANDO LOS PRIMEROS 10 JUEGOS DE "RPG", TAMBIEN SU RATING DE POPULARIDAD </h1>
# </body>
# </html>

# %%
datasetRPG = nombreRPG.head(10)
datasetRPG.drop(['Title'],axis=1)['Rating'].plot(kind='bar')
#Pero les falta algo, no tienen mayor cantidad de datos, solo es un grafico vacio
# Out:
# <Axes: >

# %% [markdown]
# <html>
# <head>
#     <title></title>
#     <style type="text/css">
#         h1
#         {
#             color: BLUE
#         }
#     </style>
# </head>
# <body>
#     <h1>MOSTRANDO LOS PRIMEROS 10 VIDEOJUEGOS + RATING + TITULO </h1>
# </body>
# </html>

# %%
datasetRPG = nombreRPG.head(10)
datasetRPG.set_index('Title', inplace=True)  # Establecer la columna 'Title' como índice
datasetRPG['Rating'].plot(x=None, kind='bar')  # Utilizar el índice en el eje x
# Out:
# <Axes: xlabel='Title'>

# %%
datasetRPG = nombreRPG.head(20)
datasetRPG.set_index('Title', inplace=True)

ax = datasetRPG['Rating'].plot(x=None, kind='bar')

#Agregando etiquetas de rating en las barras
for i, rating in enumerate(datasetRPG['Rating']):
    ax.annotate(str(rating), xy=(i, rating), ha='center', va='bottom')

plt.show()

# %% [markdown]
# <html>
# <head>
#     <title></title>
#     <style type="text/css">
#         h1
#         {
#             color: BLUE
#         }
#     </style>
# </head>
# <body>
#     <h1>PROMEDIO RATING VIDEOJUEGOS RPG </h1>
# </body>
# </html>

# %%
ratings_RPG = datos[datos['Genres'].apply(lambda x: 'RPG' in x)]['Rating']
promedio_RPG = ratings_RPG.mean()

promedio_RPG
# Out:
# 3.832558139534884

# %% [markdown]
# <html>
# <head>
#     <title></title>
#     <style type="text/css">
#         h1
#         {
#             color: BLUE
#         }
#     </style>
# </head>
# <body>
#     <h1>PROMEDIO RATING VIDEOJUEGOS Indie </h1>
# </body>
# </html>

# %%
ratings_Indie = datos[datos['Genres'].apply(lambda x: 'Indie' in x)]['Rating']
promedio_Indie = ratings_Indie.mean()

promedio_Indie
3.7031802120141344
dataset_promedios = pd.DataFrame({'Género': ['RPG', 'Indie'], 'Promedio': [promedio_RPG, promedio_Indie]})
plt.pie(dataset_promedios['Promedio'], labels=dataset_promedios['Género'], autopct='%1.1f%%')
plt.title('Promedio de Rating por Género')
plt.show()
